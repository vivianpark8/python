# %%
import fact

# %%
fact.factorial(5)
# 하위 내용 쓸 땐 . 사용
# Out:
# 120

# %%
fact.my_max(10, 100)
# Out:
# 100

# %% [markdown]
# ## 패키지
#
# ```
# myPackage/
#     __init__.py
#     math/
#         __init__.py
# ```
#
# - 패키지 안에 __init__.py 파일이 존재해야 패키지로 인식함

# %%
import myPackage

# %%
print(myPackage)
# Out:
# <module 'myPackage' from 'C:\\Users\\1-09\\Desktop\\DAMF2\\python\\myPackage\\__init__.py'>

# %%
myPackage.math.fomula.my_max(2,3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 myPackage.math.fomula.my_max(2,3)
#
# AttributeError: module 'myPackage' has no attribute 'math'

# %%
from myPackage.math.fomula import my_max

# %%
my_max(2, 3)
# Out:
# 3

# %%
from myPackage.math.fomula import *

# %%
print(pi)
# Out:
# 3.14

# %%
from myPackage.math import fomula
fomula.my_max(2, 3)
# Out:
# 3

# %%
fomula = 1234
from myPackage.math import fomula
# fomula 이름이 중복될 때
# 변수를 못 찾고 패키지를 이름으로 인식함
# fomula 라는 이름을 임시적으로 모듈 이름을 바꿀 수 있음

from myPackage.math import fomula as f
print(fomula)
print(f)
# Out:
# <module 'myPackage.math.fomula' from 'C:\\Users\\1-09\\Desktop\\DAMF2\\python\\myPackage\\math\\fomula.py'>
# <module 'myPackage.math.fomula' from 'C:\\Users\\1-09\\Desktop\\DAMF2\\python\\myPackage\\math\\fomula.py'>

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.ceil(math.e) #올림
# Out:
# 3

# %%
math.floor(math.e) #내림
# Out:
# 2

# %%
math.sqrt(9) #루트
# Out:
# 3.0

# %%
math.factorial(10)
# Out:
# 3628800

# %%
from math import sqrt, factorial

# %%
sqrt(16)
factorial(5)
# Out:
# 120

# %% [markdown]
# ### random

# %%
import random

# %%
random.random()
# Out:
# 0.43217509868832193

# %%
random.randint(1, 10)
# Out:
# 5

# %%
random.seed(123)
random.random()
# Out:
# 0.052363598850944326

# %%
numbers = [1, 2, 3, 4, 5]

# %%
random.shuffle(numbers)
print(numbers)
# Out:
# [1, 5, 2, 4, 3]

# %%
random.choice(numbers)
# Out:
# 5

# %%
random.sample(numbers, 2)
# Out:
# [5, 2]

# %% [markdown]
# ### datetime

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 2, 18, 14, 39, 3, 868982)

# %%
datetime.today()
# Out:
# datetime.datetime(2025, 2, 18, 14, 39, 52, 798986)

# %%
datetime.utcnow()
# Out:
# C:\Users\1-09\AppData\Local\Temp\ipykernel_6004\3983769260.py:1: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   datetime.utcnow()
# datetime.datetime(2025, 2, 18, 5, 40, 45, 347367)

# %%
datetime.now(timezone.utc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 datetime.now(timezone.utc)
#
# NameError: name 'timezone' is not defined

# %%
now = datetime.now()

# %%
now # 불러온 시간으로 고정됨
# Out:
# datetime.datetime(2025, 2, 18, 14, 44, 7, 490092)

# %%
print(now.year)
print(now.month)
print(now.day)
# Out:
# 2025
# 2
# 18

# %%
now.weekday() #요일 출력, 0 월
# Out:
# 1

# %%
print(now)
# Out:
# 2025-02-18 14:44:07.490092

# %%
now.strftime('%y년 %m월 %d일')
# Out:
# '25년 02월 18일'

# %%
x_mas = datetime(2025, 12, 25)
print(x_mas)
# Out:
# 2025-12-25 00:00:00

# %%
from datetime import timedelta

# %%
future = timedelta(days=3)
print(x_mas + future)
# Out:
# 2025-12-28 00:00:00

# %%
future = timedelta(days=-103)
print(x_mas + future)
# Out:
# 2025-09-13 00:00:00

# %%
x_mas - now
# Out:
# datetime.timedelta(days=309, seconds=33352, microseconds=509908)

# %% [markdown]
# ## 외부 라이브러리

# %% [markdown]
# ### requests

# %%
import requests

# %%
r = requests.get('https://api.github.com/events')

# %%
print(r)
# Out:
# <Response [200]>

# %%
print(r.text)
# Out:
# [{"id":"46711693218","type":"PullRequestEvent","actor":{"id":30536864,"login":"signcla-test-signed-indiv","display_login":"signcla-test-signed-indiv","gravatar_id":"","url":"https://api.github.com/users/signcla-test-signed-indiv","avatar_url":"https://avatars.githubusercontent.com/u/30536864?"},"repo":{"id":408894306,"name":"google-test/signclav2-probe-repo","url":"https://api.github.com/repos/google-test/signclav2-probe-repo"},"payload":{"action":"opened","number":509220,"pull_request":{"url":"https://api.github.com/repos/google-test/signclav2-probe-repo/pulls/509220","id":2343429391,"node_id":"PR_kwDOGF87Ys6LreUP","html_url":"https://github.com/google-test/signclav2-probe-repo/pull/509220","diff_url":"https://github.com/google-test/signclav2-probe-repo/pull/509220.diff","patch_url":"https://github.com/google-test/signclav2-probe-repo/pull/509220.patch","issue_url":"https://api.github.com/repos/google-test/signclav2-probe-repo/issues/509220","number":509220,"state":"open","locked":f
# ...

# %%
r= requests.get('https://naver.com')

# %%
print(r.text)
# Out:
#    <!doctype html> <html lang="ko" class="fzoom"> <head> <meta charset="utf-8"> <meta name="Referrer" content="origin"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <title>NAVER</title> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description"
# ...

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get('https://httpbin.org/get', params=payload)

# %%
print(r.url)
print(r.text)
# Out:
# https://httpbin.org/get?key1=value1&key2=value2
# {
#   "args": {
#     "key1": "value1",
#     "key2": "value2"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.32.3",
#     "X-Amzn-Trace-Id": "Root=1-67b52f77-759cde670e7e4abe4def6286"
#   },
#   "origin": "183.96.187.252",
#   "url": "https://httpbin.org/get?key1=value1&key2=value2"
# }

# %%
payload = {'query': '파이썬'}
r = requests.get('https://search.naver.com/search.naver', params=payload)
print(r.url)
# Out:
# https://search.naver.com/search.naver?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC

# %%
print(type(r.text))
# Out:
# <class 'str'>

# %%
r = requests.get('https://api.github.com/events')
print(type(r.json()))
print(r.json()['message'])
# Out:
# <class 'dict'>
# API rate limit exceeded for 183.96.187.252. (But here's the good news: Authenticated requests get a higher rate limit. Check out the documentation for more details.)

# %%
lotto_url = 'https://www.dhlottery.co.kr/common.do'

# 딕셔너리로 정보 만들기
payload = {
    'method': 'getLottoNumber',
    'drwNo': 1159,
}

r = requests.get(lotto_url, params=payload)
print(r.url)

print(r.text)

lotto_dict = r.json()
print(lotto_dict['drwNoDate'])
#print(lotto_dict['drwtNo1'])
#print(lotto_dict['drwtNo2'])
#print(lotto_dict['drwtNo3'])
#print(lotto_dict['drwtNo4'])
#print(lotto_dict['drwtNo5'])
#print(lotto_dict['drwtNo6'])

for i in range(1, 6):
    print(lotto_dict[f'drwtNo{i}'])
# Out:
# https://www.dhlottery.co.kr/common.do?method=getLottoNumber&drwNo=1159
# {"totSellamnt":124802304000,"returnValue":"success","drwNoDate":"2025-02-15","firstWinamnt":1284854250,"drwtNo6":39,"drwtNo4":28,"firstPrzwnerCo":23,"drwtNo5":38,"bnusNo":7,"firstAccumamnt":29551647750,"drwNo":1159,"drwtNo2":9,"drwtNo3":27,"drwtNo1":3}
# 2025-02-15
# 3
# 9
# 27
# 28
# 38

# %% [markdown]
# ### 페어프로그래밍 (로또)
# - 로또 5000원 구매하기
#     - 랜덤으로 5개의 로또 번호 생성
# - 등수 확인하기
#     - 최신 회차의 당첨번호와 생성된 번호 비교하여 각각 몇 등인지 출력

# %%
# 1. 로또 번호 생성하기

import random

my_numbers = {}

for i in range(1, 6):
    random_numbers = random.sample(range(1, 46), 6)
    random_numbers.sort() #오름차순
    my_numbers[i] = random_numbers #i라는 key에 random_numbers라는 value 넣기
    
print(my_numbers)
# Out:
# {1: [2, 7, 11, 18, 28, 36], 2: [11, 13, 20, 27, 40, 42], 3: [3, 11, 15, 17, 25, 40], 4: [6, 12, 18, 20, 22, 26], 5: [2, 12, 23, 34, 39, 44]}

# %%
# 2. 최신 회차 당첨번호 수집

LOTTO_URL = 'https://www.dhlottery.co.kr/common.do' #변하지 않을 땐 전부 대문자
payload = {
    'method': 'getLottoNumber',
    'drwNo': 1159,
}

res = requests.get(LOTTO_URL, params=payload)
lotto_dict = res.json()
print(lotto_dict)

# 당첨번호 뽑아오기
lucky_numbers = []
bonus_number = lotto_dict['bnusNo']

# for i in range() 반복 횟수를 알 때

for k, v in lotto_dict.items(): # 딕셔너리의 모든 정보를 읽어보기
    if 'drwtNo' in k: # key값에 이 글자가 포함되어 있다면
        lucky_numbers.append(v) # value를 리스트에 추가

print(my_numbers)
print(lucky_numbers)
print(bonus_number)
# Out:
# {'totSellamnt': 124802304000, 'returnValue': 'success', 'drwNoDate': '2025-02-15', 'firstWinamnt': 1284854250, 'drwtNo6': 39, 'drwtNo4': 28, 'firstPrzwnerCo': 23, 'drwtNo5': 38, 'bnusNo': 7, 'firstAccumamnt': 29551647750, 'drwNo': 1159, 'drwtNo2': 9, 'drwtNo3': 27, 'drwtNo1': 3}
# {1: [2, 7, 11, 18, 28, 36], 2: [11, 13, 20, 27, 40, 42], 3: [3, 11, 15, 17, 25, 40], 4: [6, 12, 18, 20, 22, 26], 5: [2, 12, 23, 34, 39, 44]}
# [39, 28, 38, 9, 27, 3]
# 7

# %%
# 3. 등수 확인하기

# 방법1: for문으로 반복시키기
for key, value in my_numbers.items():
    for i in value:
        for j in range(6):
            if i == lucky_numbers[j]:
                #...

# %%
# 방법2: set의 교집합 뽑고 당첨번호와 비교하기

for my_number in my_numbers.values():
    my_number_set = set(my_number)
    lucky_numbers_set = set(lucky_numbers)

    # 교집합 찾기
    match_count = len(my_number_set & lucky_numbers_set) #교집합의 개수

    if match_count == 6:
        print('1등')
    elif match_count == 5 and bonus_number in my_number:
        print('2등')
    elif match_count == 5:
        print('3등')
    elif match_count == 4:
        print('4등')
    elif match_count == 3:
        print('5등')
    else:
        print('꽝')
# Out:
# 꽝
# 꽝
# 꽝
# 꽝
# 꽝
